# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2,3]
y=[4,5,6]

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %% [markdown]
# Univariate Analysis:
# Here we only analyze one single data or feature

# %%
data={ "Salary": [25000,30000,37000,28000,39000,48000,55000,52000,35000,26000,28000,27000,31000,45000,52000]}

# %%
df= pd.DataFrame(data)
df.head()
# Out:
#    Salary
# 0   25000
# 1   30000
# 2   37000
# 3   28000
# 4   39000

# %%
df.shape
# Out:
# (15, 1)

# %%
# Line Plot
plt.plot(df["Salary"], color="red", marker="*", linestyle=":", linewidth="1")
plt.grid()
plt.show()

# %%
plt.hist(df['Salary'], bins=5, color="green")
plt.show()

# %%
# df.loc[15]=0
plt.boxplot(df["Salary"])
plt.show()

# %% [markdown]
# Univariate Categorical columns

# %%
df["dept"]=["IT","HR","Sales","Finance","IT","Sales","HR","HR","Sales","Finance","Sales","Finance","HR","IT","Sales"]
df.head()
# Out:
#    Salary Department     dept
# 0   25000         IT       IT
# 1   30000         HR       HR
# 2   37000      Sales    Sales
# 3   28000    Finance  Finance
# 4   39000         IT       IT

# %%
# Pie Chart
count= df['dept'].value_counts()
plt.pie(count, labels=count.index, autopct="%1.2f",explode=[0.1,0,0,0])
plt.axis("equal")
plt.show()

# %%
# countplot

plt.bar(count.index, count, color=['green','black','red','blue'])
plt.show()
