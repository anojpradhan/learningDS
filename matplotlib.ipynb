# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=[1,2,3]
y=[4,5,6]

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %% [markdown]
# Univariate Analysis:
# Here we only analyze one single data or feature

# %%
data={ "Salary": [25000, 26000, 27000, 28000, 28000, 30000, 31000, 35000, 37000, 39000, 45000, 48000, 52000, 52000, 55000]}

# %%
df= pd.DataFrame(data)
df.head()
# Out:
#    Salary
# 0   25000
# 1   26000
# 2   27000
# 3   28000
# 4   28000

# %%
df.shape
# Out:
# (15, 1)

# %%
# Line Plot
plt.plot(df["Salary"], color="red", marker="*", linestyle=":", linewidth="1")
plt.grid()
plt.show()

# %%
plt.hist(df['Salary'], bins=5, color="green")
plt.show()

# %%
# df.loc[15]=0
plt.boxplot(df["Salary"])
plt.show()

# %% [markdown]
# Univariate Categorical columns

# %%
df["dept"]=["IT","HR","Sales","Finance","IT","Sales","HR","HR","Sales","Finance","Sales","Finance","HR","IT","Sales"]
df.head()
# Out:
#    Salary     dept
# 0   25000       IT
# 1   26000       HR
# 2   27000    Sales
# 3   28000  Finance
# 4   28000       IT

# %%
# Pie Chart
count= df['dept'].value_counts()
plt.pie(count, labels=count.index, autopct="%1.2f",explode=[0.1,0,0,0])
plt.axis("equal")
plt.show()

# %%
# countplot

plt.bar(count.index, count, color=['green','black','red','blue'])
plt.show()

# %%
# Bivariate Analysis- numeric columns

df["Age"]=[20, 23, 27, 28, 29, 32, 32, 33, 34, 34, 45, 45, 45, 56, 67]
# df.shape
df.head()
# Out:
#    Salary     dept  Age
# 0   25000       IT   20
# 1   26000       HR   23
# 2   27000    Sales   27
# 3   28000  Finance   28
# 4   28000       IT   29

# %%
# scatter plot
plt.scatter(df["Age"], df['Salary'], color='orange')
plt.show()

# %%
# line plot 
plt.plot(df["Age"],df["Salary"], color='red', marker='o', linestyle="--")
plt.grid()
plt.show()

# %%
# Bar chart 
plt.bar(df['Age'], df['Salary'], color='green', align="center")
plt.show()

# %% [markdown]
# Bivariate Analysis (Numerical - Categorical)

# %%
hr_salaries= df[df["dept"]== "HR"]["Salary"]
hr_salaries
# Out:
# 1     26000
# 6     31000
# 7     35000
# 12    52000
# Name: Salary, dtype: int64

# %%
it_salaries= df[df["dept"]== "IT"]["Salary"]
it_salaries
# Out:
# 0     25000
# 4     28000
# 13    52000
# Name: Salary, dtype: int64

# %%
sales_salaries= df[df["dept"]== "Sales"]["Salary"]
sales_salaries
# Out:
# 2     27000
# 5     30000
# 8     37000
# 10    45000
# 14    55000
# Name: Salary, dtype: int64

# %%
fin_salaries= df[df["dept"]== "Finance"]["Salary"]
fin_salaries
# Out:
# 3     28000
# 9     39000
# 11    48000
# Name: Salary, dtype: int64

# %%
# boxplot 
plt.boxplot([hr_salaries,fin_salaries,it_salaries,sales_salaries], label=['Hr','finance','IT','Sales'], orientation='horizontal')
plt.legend()
plt.show()

# %%
# piechart
salary_by_dept= df.groupby("dept")["Salary"].sum()
salary_by_dept
# Out:
# dept
# Finance    115000
# HR         144000
# IT         105000
# Sales      194000
# Name: Salary, dtype: int64

# %%
plt.pie(salary_by_dept,labels= salary_by_dept.index, autopct="%1.2f")
plt.axis("equal")
plt.show()

# %%
# bar plot
hr_sal_mean= sum(hr_salaries)/len(hr_salaries)
it_sal_mean= sum(it_salaries)/len(it_salaries)
sales_sal_mean= sum(sales_salaries)/len(sales_salaries)
fin_sal_mean= sum(fin_salaries)/len(fin_salaries)
plt.bar(["HR","IT","Sales","Finance"], [hr_sal_mean,it_sal_mean,sales_sal_mean,fin_sal_mean], color=['green','red','black','blue'])
plt.grid()
plt.show()

# %% [markdown]
# Multivariate analysis: numeric columns

# %%
df.head()
# Out:
#    Salary     dept  Age
# 0   25000       IT   20
# 1   26000       HR   23
# 2   27000    Sales   27
# 3   28000  Finance   28
# 4   28000       IT   29

# %%
df['Exp']= [1,1,1,2,2,2,2,3,3,4,4,4,5,5,5]

# %%
df.head()
# Out:
#    Salary     dept  Age  Exp
# 0   25000       IT   20    1
# 1   26000       HR   23    1
# 2   27000    Sales   27    1
# 3   28000  Finance   28    2
# 4   28000       IT   29    2

# %%
df.shape
# Out:
# (15, 4)

# %%
# Bubble Plot
plt.scatter(df["Age"], df["Salary"],s= df["Exp"]*30,edgecolors="black" ,color="red")
plt.title("Age vs Salary vs Experience")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %%
# 2 numeric amd 1 categorical
colors= {"HR":"yellow","IT":"blue","Finance":"red","Sales":"black"}
for dept,color in colors.items():
    df_dept=df[df['dept']==dept]
    plt.scatter(df_dept["Age"],df_dept["Salary"],c=color, label=dept)
plt.legend()
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# Object Oriented API

# %%
# OO-Api in matplotlib 
fig, axs = plt.subplots(1,3, figsize=(10,5))
# Line plot
axs[0].plot(df["Age"], df["Salary"], color="red", marker="*",)
axs[0].grid()
axs[0].set_title("Age vs Salary")
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Salary")

# HistoGram
axs[1].hist(df["Salary"], bins=5, color= "skyblue" ,edgecolor='black')
axs[1].set_xlabel("Salary")
axs[1].set_ylabel("Frequency")
axs[1].set_title("Salary Histogram")


#Box Plot

axs[2].boxplot(df["Salary"])
axs[2].set_title(" Boxplot of Salary")
axs[2].set_xlabel(" Salary")
plt.show()

# %%
data2={
    'Year':[2000,2005,2010,2015],
    'Sales':[100,150,200,250],
    'Profit':[20,30,40,50],
    'Expense':[80,120,160,200]
}

# %%
df2= pd.DataFrame(data2)
df2.head()
# Out:
#    Year  Sales  Profit  Expense
# 0  2000    100      20       80
# 1  2005    150      30      120
# 2  2010    200      40      160
# 3  2015    250      50      200

# %%
plt.plot(df2["Year"],df2["Sales"], label="Sales", color='black')
plt.plot(df2["Year"],df2["Profit"], label="Profit", color='orange')
plt.plot(df2["Year"],df2["Expense"], label="Expenses", color='skyblue')
plt.title("financial analysis")
plt.xlabel("Year")
plt.ylabel("Amount")
plt.legend()
plt.show()

# %% [markdown]
# 3D Plot

# %%
ax= plt.axes(projection= '3d')
ax.scatter(df["Age"], df["Salary"], df["Exp"])
ax.set_xlabel("Age")
ax.set_ylabel("Salary")
ax.set_zlabel("Experience")
plt.show()

# %%
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.7 MB 2.4 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/9.7 MB 2.4 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.7 MB 2.4 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.7 MB 2.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.7 MB 2.4 MB/s eta 0:00:03
#    -------------- ------------------------- 3.4/9.7 MB 2.4 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.7 MB 2.4 MB/s eta 0:00:03
#    ------------------ --------------------- 4.5/9.7 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 5.0/9.7 MB 2.4 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.7 MB 2.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.8/9.7 MB 2.4 MB/s eta 0:00:02
# ...

# %%
import plotly.express as px

fig= px.scatter_3d(df,x="Age",y ="Salary", z="Exp", title= "3D Scatter Plot", color="dept",)
fig.show()
